# %% [markdown]
# SVM :- Support vector machine
# svm is one  of the most popular supervised learnong algorithem, which is used for classification as well as regression problems

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\birthday\creditcard.csv")
dataset.head()

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["Class"]

# %%
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %% [markdown]
# from sklearn.svm import SVR
# sv = SVC(kernel="linear")
# sv.fit(x_train, y_train)#have no dataset to applythis classification

# %% [markdown]
# sv.score(x_test, y_test)

# %% [markdown]
# sv.score(x_train, y_train)

# %% [markdown]
# ### Regression of svm

# %% [markdown]
# from sklearn.svm import SVR
# sv.fit(kernel="linear,sigmoid,poly etc")

# %% [markdown]
# sr.fit(x_train,y_train)
# sr.score(x_test,y_test)

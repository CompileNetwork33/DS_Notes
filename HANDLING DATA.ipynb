# %%
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel(r"C:\Users\kashi\OneDrive\Book 1.xlsx")
dataset.head()

# %%
dataset.shape

# %%
dataset.isnull().sum()
(dataset.isnull().sum()/dataset.shape[0])*100

# %%
dataset.isnull().sum().sum()#total null value calculate krta hai 
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100#total null value percentage calculate krta hai

# %%
dataset.notnull().sum().sum()

# %%
sea.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(
    dataset.columns[dataset.columns.str.contains('^Unnamed')],
    axis=1,
    inplace=True
)

# %%
dataset.columns

# %%
dataset.dropna(inplace=True)
dataset.isnull().sum()
dataset.shape

# %%
((18-10)/18)*100#% of data lost agter removing null values

# %% [markdown]
# # now missing values fill krna hai

# %%
dataset.fillna(method='ffill')

# %%
dataset.fillna(method='bfill',axis=1)

# %%
dataset['WDS'].mode()[0]

# %%
dataset.info()

# %%
dataset.select_dtypes(include=['float64']).columns

# %% [markdown]
# Scikit-learn kya hai?
#
# Open-source Python library
#
# Built on NumPy, Pandas, Matplotlib
#
# Easy syntax, industry-standard
#
# Mostly classical ML algorithms (not deep learning)
#
# cikit-learn ka ML Workflow (MOST IMPORTANT)
#
# Interview me directly pucha jata hai 👇
#
# 1️⃣ Data load
# 2️⃣ Data preprocessing
# 3️⃣ Train–test split
# 4️⃣ Model select
# 5️⃣ Model train
# 6️⃣ Prediction
# 7️⃣ Evaluation

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy='mean')#mean, 
si.fit_transform(dataset[['SALARRY', 'OVERTIME', 'WDS', 'OTS', 'TOTAL', 'ADVANCE', 'NET SALARY',
       'Unnamed: 9', 'Unnamed: 10']])

# %%
dataset['WORKING DAYS'].mean()#mean nikalna kisis ka bhi column ka

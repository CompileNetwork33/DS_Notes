# %% [markdown]
# # Machine Learning

# %% [markdown]
# Data Cleaning in Machine Learning
# 1️⃣ Handling Missing Values
#
# Sometimes datasets have NaN / null values.

# %% [markdown]
# ***Methods***
#
# 1. Remove rows
#
# df.dropna()
#
# 2. Fill with mean
#
# df["Age"].fillna(df["Age"].mean())
#
# 3. Fill with median
#
# df["Age"].fillna(df["Age"].median())
#
# 4. Fill with mode (for categorical data)
#
# df["City"].fillna(df["City"].mode()[0])

# %% [markdown]
#  ## Missing values and how can find it
#  In Machine Learning / Data Analysis, a missing value means data that is not stored or is unavailable in the dataset. Instead of an actual value, the dataset may contain NaN, NULL, or blank cells.
#
# What is a Missing Value?
#
# A missing value is when a feature has no data for some observations.
#
# Example dataset:
#
# Name	Age	Salary
# Ravi	25	50000
# Aman	NaN	60000
# Neha	30	NaN
#
# Here:
#
# Age for Aman is missing
#
# Salary for Neha is missing
#
# In Python (Pandas), missing values are usually shown as NaN.

# %% [markdown]
# ***Why Missing Values Occur***
#
# Common reasons:
#
# Data not collected
#
# User skipped a form field
#
# Data corruption
#
# Errors during data entry
#
# Data merging issues

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Feature Selection Techniques in Machine Learning
#
# 1️⃣ Filter Methods
#
# Isme features ko model train kiye bina statistical methods se select kiya jata hai.
#
# Common Techniques
#
# Correlation
#
# Chi-Square Test
#
# Information Gain
#
# Variance Threshold
#
# Example
#
# Agar kisi feature ki variance bahut kam hai, to uska data almost same hoga → us feature ka model me koi contribution nahi.
#
# ✔ Fast
# ✔ Simple
# ❌ Feature interaction consider nahi karta

# %% [markdown]
# Wrapper Methods:-
#
# Is method me model ko train karke different feature combinations test kiye jate hain.
#
# Techniques
#
# Forward Selection
#
# Backward Elimination
#
# Recursive Feature Elimination (RFE)
#
# **Forward Selection**
#
# Start → 0 features
#
# Ek-ek feature add karte hain
#
# Jo model accuracy improve kare usko keep karte hain
#
# Example
#
# Start → none
# Step1 → add Age
# Step2 → add Salary
# Step3 → add Experience
#
# **Backward Elimination**
#
# Start → all features
#
# Least important feature remove karte hain
#
# Example
#
# Start → Age, Salary, Experience, City
#
# Remove → City (least important)
#
# ***Recursive Feature Elimination (RFE)***
#
# Model train hota hai
#
# Least important features remove hote hain
#
# Process repeat hota hai

# %% [markdown]
# 3️⃣ Embedded Methods
#
# Isme feature selection model training ke andar hi hota hai.
#
# Examples
#
# Lasso Regression (L1 Regularization)
#
# Decision Tree
#
# Random Forest Feature Importance

# %% [markdown]
# ### Polynomial regression

# %% [markdown]
# olynomial Regression is a type of regression where the relationship between input (X) and output (Y) is curved instead of a straight line.
#
# In Linear Regression → we fit a straight line
# In Polynomial Regression → we fit a curve

# %% [markdown]
# Polynomial Regression (Curve)
#
# Example:
#
# Age vs Salary
# Temperature vs Sales
# These usually form curves
# Polynomial Regression Formula
#
# 𝑦
# =
# 𝑎
# 0
# +
# 𝑎
# 1
# 𝑥
# +
# 𝑎
# 2
# 𝑥
# 2
# +
# 𝑎
# 3
# 𝑥
# 3
# +
# ⋯
# +
# 𝑎
# 𝑛
# 𝑥
# 𝑛
# y=a
# 0
# 	​
#
# +a
# 1
# 	​
#
# x+a
# 2
# 	​
#
# x
# 2
# +a
# 3
# 	​
#
# x
# 3
# +⋯+a
# n
# 	​
#
# x
# n
#
# Where:
#
# x = input variable
# y = output variable
# a₀, a₁, a₂... = coefficients
# n = degree of polynomial

# %% [markdown]
# When to Use Polynomial Regression
#
# Use it when:
#
# Data is curved
# Linear regression gives poor accuracy
# Relationship is non-linear

# %% [markdown]
# # Cost Function

# %% [markdown]
# ost Function simply means "model kitni galti kar raha hai" measure karne ka tarika.
#
# Machine Learning me cost function batata hai ki prediction aur actual value me kitna difference hai.
#
# Simple Example
#
# Suppose:
#
# Actual Price	Predicted Price
# 100	90
# 200	220
#
# Yaha model galti kar raha hai.
# Cost function in sab galtiyon ko ek number me convert karta hai.

# %% [markdown]
# Most Common Cost Functions
# 1. Mean Squared Error (MSE) — Regression me use hota hai
#
# Formula:
#
# 𝑀
# 𝑆
# 𝐸
# =
# 1
# 𝑛
# ∑
# (
# 𝐴
# 𝑐
# 𝑡
# 𝑢
# 𝑎
# 𝑙
# −
# 𝑃
# 𝑟
# 𝑒
# 𝑑
# 𝑖
# 𝑐
# 𝑡
# 𝑒
# 𝑑
# )
# 2
# MSE=
# n
# 1
# 	​
#
# ∑(Actual−Predicted)
# 2
#
# Simple meaning:
#
# Actual − Predicted → error
# Square → negative hatane ke liye
# Average → final cost
#
# 👉 Goal: Cost ko minimum karna

# %% [markdown]
# 2. Mean Absolute Error (MAE)
# 𝑀
# 𝐴
# 𝐸
# =
# 1
# 𝑛
# ∑
# ∣
# 𝐴
# 𝑐
# 𝑡
# 𝑢
# 𝑎
# 𝑙
# −
# 𝑃
# 𝑟
# 𝑒
# 𝑑
# 𝑖
# 𝑐
# 𝑡
# 𝑒
# 𝑑
# ∣
# MAE=
# n
# 1
# 	​
#
# ∑∣Actual−Predicted∣
#
# Yeh simply absolute error ka average hota hai.
#
# Why Cost Function Important? 🤔
# Model ki performance check karne ke liye
# Model ko improve karne ke liye
# Best prediction find karne ke liye
#
# 👉 Machine Learning ka main goal hota hai:

# %% [markdown]
# Real-life Example 🎯
#
# Agar tum house price prediction model bana rahi ho:
#
# Prediction wrong → cost high
# Prediction accurate → cost low

# %% [markdown]
# ### Regularization kya hota hai?
#
# Regularization ek technique hai jo machine learning models ko overfitting se bachati hai.
#
# 👉 Overfitting = jab model training data ko itna yaad kar leta hai ki new data par achha perform nahi karta.
#
# 🔹 Simple idea
#
# Model ko thoda “control” karna:
#
# “Zyada complex mat ban, simple reh aur generalize kar.”
